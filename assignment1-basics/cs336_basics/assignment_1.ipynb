# %% [markdown]
# ### Problem (unicode1):  Understanding Unicode (1 point)

# %%
chr(0)
# Out:
# '\x00'

# %%
print(chr(0))

# %%
print("this is a test"+chr(0)+"string")
# Out:
# this is a teststring

# %%
test_string="hello! こんにちは!"
utf_8_encoded = test_string.encode("utf-8")
print(utf_8_encoded)
# Out:
# b'hello! \xe3\x81\x93\xe3\x82\x93\xe3\x81\xab\xe3\x81\xa1\xe3\x81\xaf!'

# %%
print(type(utf_8_encoded))
# Out:
# <class 'bytes'>

# %%
list(utf_8_encoded)
# Out:
# [104,
#  101,
#  108,
#  108,
#  111,
#  33,
#  32,
#  227,
#  129,
#  147,
#  227,
#  130,
#  147,
#  227,
#  129,
#  171,
#  227,
#  129,
#  161,
#  227,
#  129,
#  175,
#  33]

# %%
print(len(test_string))
print(len(utf_8_encoded))
print(utf_8_encoded.decode("utf-8"))
# Out:
# 13
# 23
# hello! こんにちは!

# %%
test_string="hello! こんにちは!"
utf_16_encoded = test_string.encode("utf-16")
print(utf_16_encoded)
print(len(test_string))
print(len(utf_16_encoded))
print(utf_16_encoded.decode("utf-16"))
# Out:
# b'\xff\xfeh\x00e\x00l\x00l\x00o\x00!\x00 \x00S0\x930k0a0o0!\x00'
# 13
# 28
# hello! こんにちは!

# %%
test_string="hello! こんにちは!"
utf_32_encoded = test_string.encode("utf-32")
print(utf_32_encoded)
print(len(test_string))
print(len(utf_32_encoded))
print(utf_32_encoded.decode("utf-32"))
# Out:
# b'\xff\xfe\x00\x00h\x00\x00\x00e\x00\x00\x00l\x00\x00\x00l\x00\x00\x00o\x00\x00\x00!\x00\x00\x00 \x00\x00\x00S0\x00\x00\x930\x00\x00k0\x00\x00a0\x00\x00o0\x00\x00!\x00\x00\x00'
# 13
# 56
# hello! こんにちは!

# %%
def decode_utf8_bytes_to_str_wrong(bytestring: bytes):
    return "".join([bytes([b]).decode("utf-8") for b in bytestring])

# %%
decode_utf8_bytes_to_str_wrong("b\xff'".encode("utf-8"))
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 decode_utf8_bytes_to_str_wrong("b\xff'".encode("utf-8"))
#
# Cell In[9], line 2, in decode_utf8_bytes_to_str_wrong(bytestring)
#       1 def decode_utf8_bytes_to_str_wrong(bytestring: bytes):
# ----> 2     return "".join([bytes([b]).decode("utf-8") for b in bytestring])
#
# Cell In[9], line 2, in <listcomp>(.0)
#       1 def decode_utf8_bytes_to_str_wrong(bytestring: bytes):
# ----> 2     return "".join([bytes([b]).decode("utf-8") for b in bytestring])
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc3 in position 0: unexpected end of data

# %% [markdown]
# It fails because you decode each single byte as UTF‑8, but bytes >= 0x80 (e.g., 0xFF) can be part of multi‑byte UTF‑8 sequences and cannot be decoded alone, causing a UnicodeDecodeError.

# %% [markdown]
# Example: the two-byte sequence 0xC3 0x20 (bytes literal b'\xc3 ') — invalid UTF‑8 because 0xC3 requires a continuation byte in 0x80–0xBF.

# %%
PAT =  r"""'(?:[sdmt]|ll|ve|re)| ?\p{L}+| ?\p{N}+| ?[^\s\p{L}\p{N}]+|\s+(?!\S)|\s+"""
import regex as re
re.findall(PAT , "Tokenization in Transformers v5: Simpler, Clearer, and More Modular")
# Out:
# ['Tokenization',
#  ' in',
#  ' Transformers',
#  ' v',
#  '5',
#  ':',
#  ' Simpler',
#  ',',
#  ' Clearer',
#  ',',
#  ' and',
#  ' More',
#  ' Modular']
